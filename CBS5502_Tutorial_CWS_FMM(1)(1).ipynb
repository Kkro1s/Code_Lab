# %% [markdown]
# <div align="center">
#
# # 🧠 **CBS5502 — Computational Linguistics and NLP Technologies**
#
# ### 🐍 **1st Python Tutorial**
# ### 📅 *January 28, 2026*
#
# ---
#
# ## 🇨🇳 **Chinese Word Segmentation**
# ### ✂️ *Forward Maximum Matching (FMM) Algorithm*
# ### ✍️ Apply to *Backward Maximum Matching (BMM) Algorithm*
#
# ---
# ### 👨‍🏫 **Instructor**
# **Dr. WAN Mingyu**
#
# ### 👨‍🏫 **Teaching Assistant**
# **Mr. BAO Xiaoyi**
#
#
# </div>
#
# ---
#
# ## 🌟 Welcome!
#
# Welcome to the **first tutorial of CBS5502**!
# In this session, we will step into the foundations of **Chinese Word Segmentation**, an important initial task in **Natural Language Processing (NLP)**, by implementing **self-built algorithms: FMM/BMM**.
#
# ### 🎯 Learning Objectives
#
# By the end of this tutorial, you will be able to:
#
# - ✅ Understand the task of **Chinese word segmentation**
# - ✅ Explain the **core idea of the FMM/BMM algorithms**
# - ✅ Implement **FMM and BMM from scratch in Python**
# - ✅ Compare the two methods with existing segmentation tools
#
# ---
# This tutorial emphasizes **hands-on implementation** and **clear algorithmic thinking**.  No prior experience with Chinese NLP is required—just curiosity and enthusiasm to learn!
#
# > 💡 *Tip:* Read the explanations carefully and try modifying the code to deepen your understanding.
#
# ---
#
# ## 🚀 Let’s Get Started!

# %% [markdown]
# ---
#
# # 🧠 Step-by-Step Tutorial
# ## Chinese Word Segmentation with **Forward Maximum Matching (FMM)**
# *(For Beginners with Little or No Python Experience)*
#
# ---
#
# ## 🇨🇳 Why Do We Need Chinese Word Segmentation?
#
# Unlike English, **Chinese sentences do not have spaces** between words.
#
# Example:
#
# ```text
# 他們邀請了離島區議員列席。
#
# Computers see this as one long string, but humans see words:
#
# 他們 / 邀請 / 了 / 離島 / 區議員 / 列席 / 。 or
# 他們 / 邀請 / 了 / 離島區 / 議員 / 列席 /
#
# 👉 Word segmentation is the task of splitting a sentence into meaningful words.

# %% [markdown]
# ## ✂️ What Is Forward Maximum Matching (FMM)?
#
# **Forward Maximum Matching (FMM)** is a **simple and classical algorithm** widely used in  **Chinese word segmentation**.
#
# ✨ FMM is easy to understand, fast to implement, and a great starting point for learning Natural Language Processing (NLP).
#
# Because Chinese text does not contain spaces, FMM helps computers decide **where one word ends and the next begins**.
#
# ---
#
# ### 🔍 How Does FMM Work?
#
# FMM follows these steps **from left to right**:
#
# 1. **Start from the beginning** of the sentence
# 2. **Look ahead** and try to match the **longest possible word** in the dictionary
# 3. ✅ **If a word is found** → accept it and move the pointer forward
# 4. ❌ **If no word is found** → take **one single character** as a word
# 5. 🔁 **Repeat** the process until the sentence ends
#
# ---
#
# ### 📌 Key Idea
#
# > **“Always try the longest word first.”**
#
# This strategy helps reduce incorrect splitting by **prioritizing meaningful longer words** over shorter ones.
#
# ---
#
# ### 🧠 Simple Example
#
# Sentence:
# ```text
# 南京市長江大橋
#
# Dictionary contains: 南京市, 南京, 市長, 長江, 大橋, 長江大橋
#
# FMM result:
# 南京市 / 長江大橋
#
# ✅ The algorithm prefers 長江大橋 (4 characters)
# ❌ instead of splitting it into 長江 / 大橋

# %% [markdown]
# ---
#
# # 🧠 Implementation
# ## Forward Maximum Matching (FMM) for Chinese Word Segmentation
#
# ---

# %% [markdown]
# ## **Forward Maximum Matching algorithm for Chinese word segmentation**
#
# Replicate and understand the following codes for the task, and try a few things:
#
# - Change the input sentence with other interesting test samples
# - Adapt the current codes to BMM
# - Discuss the limitation of the current methods for word ambiguity
# - Extended Learning: call tokenizer in Jieba and compare the results

# %%
# ------------------------------------------------------------
# Forward Maximum Matching (FMM)
# Chinese Word Segmentation – Beginner Friendly Version
# ------------------------------------------------------------

def forward_maximum_matching(sentence, dictionary):
    """
    Segment a Chinese sentence using Forward Maximum Matching (FMM).

    Parameters
    ----------
    sentence : str
        The Chinese sentence to be segmented.
    dictionary : set
        A set of known words.

    Returns
    -------
    list
        A list of segmented words.
    """

    # --------------------------------------------------------
    # Step 1: Find the maximum word length in the dictionary
    # --------------------------------------------------------
    # This tells us how many characters we should try at most.
    max_word_length = 0
    for word in dictionary:
        if len(word) > max_word_length:
            max_word_length = len(word)

    # --------------------------------------------------------
    # Step 2: Prepare variables
    # --------------------------------------------------------
    segmented_words = []   # This list will store the result
    current_position = 0   # Pointer to the current position in the sentence

    # --------------------------------------------------------
    # Step 3: Process the sentence from left to right
    # --------------------------------------------------------
    while current_position < len(sentence):

        # Assume no word is matched at the current position
        found_word = False

        # ----------------------------------------------------
        # Step 4: Try to match the longest word first
        # ----------------------------------------------------
        for word_length in range(max_word_length, 0, -1):

            # If the word goes beyond the sentence, skip it
            if current_position + word_length > len(sentence):
                continue

            # Extract a candidate word from the sentence
            candidate_word = sentence[
                current_position : current_position + word_length
            ]

            # Check if this word exists in the dictionary
            if candidate_word in dictionary:
                segmented_words.append(candidate_word)
                current_position += word_length
                found_word = True
                break  # Stop after finding the longest match

        # ----------------------------------------------------
        # Step 5: If no word is found, take one character
        # ----------------------------------------------------
        if not found_word:
            segmented_words.append(sentence[current_position])
            current_position += 1

    # --------------------------------------------------------
    # Step 6: Return the segmentation result
    # --------------------------------------------------------
    return segmented_words


# ------------------------------------------------------------
# Example Usage
# ------------------------------------------------------------

# Dictionary (known words)
dictionary = {
    "他們", "我們", "邀請", "受邀", "了", "是",
    "離島", "港島", "區議員", "列席", "出席", "區", "議員"
}

# Input sentence
sentence = "他們邀請了離島區議員列席。"

# Run FMM segmentation
result = forward_maximum_matching(sentence, dictionary)

# Display the result
print("Segmented Sentence:")
print(" / ".join(result))
# Out:
# Segmented Sentence: 他們 / 邀請 / 了 / 離島 / 區議員 / 列席 / 。

# %% [markdown]
# ---
#
# ## ✍️ Exercise 1: Backward Maximum Matching (BMM)
#
# In this exercise, you will **modify the Forward Maximum Matching (FMM) code**
# to implement **Backward Maximum Matching (BMM)** for **Chinese Word Segmentation**.
#
# This task helps you understand **how direction affects segmentation**.
#
# ---
#
# ## 🔄 What Is Backward Maximum Matching (BMM)?
#
# **Backward Maximum Matching (BMM)** works almost the same as FMM, **but in reverse**:
#
# | FMM | BMM |
# |----|----|
# | Start from the **beginning** | Start from the **end** |
# | Move **left → right** | Move **right → left** |
# | Try longest word first | Try longest word first |
#
# 📌 **Key idea**:
# > *Always try the longest word, but from the end of the sentence.*
#
# ---
#
# ## 🎯 Your Task
#
# You will:
#
# 1. **Reuse the FMM code**
# 2. Change the logic to:
#    - Start from the **end** of the sentence
#    - Move **backward**
# 3. Segment the sentence using **BMM**
#
# ---

# %% [markdown]
# ---
#
# ## ✍️ Exercise 2: Using Existing Word Segmentation Tools
# ### Comparing **FMM / BMM**, **NLTK**, and **Jieba**
#
# In this exercise, you will **apply existing word segmentation tools** to the **same Chinese sentence** and **compare the results** with your own **FMM/BMM implementations**.
#
# The goal is to understand:
#
# - ✅ How real NLP tools perform word segmentation
# - ✅ The **strengths and weaknesses** of rule-based vs. statistical methods
# - ✅ How **word meaning resolution (ambiguity)** is handled differently
#
# ---
#
# ## 🎯 Task Overview
#
# You will:
#
# 1. Segment the same sentence using:
#    - ✅ Your own **FMM / BMM**
#    - ✅ **NLTK** (baseline / limitation observation)
#    - ✅ **Jieba**
# 2. Compare the segmentation results
# 3. Discuss **why results differ**
# 4. Analyze how each method handles **ambiguity and word meaning**
#
# ---
#
# ## 🧪 Test Sentence (Same as Before)
#
# ```python
# sentence = "他們邀請了離島區議員列席。"

# %%
# ============================================================
# Exercise: Comparing Word Segmentation Methods
# FMM / BMM (Self-built) vs NLTK vs Jieba
# ============================================================

sentence = "他們邀請了離島區議員列席。"

# A tiny dictionary for demonstration (you can expand it)
word_dict = {
    "他們", "邀請", "了", "離島", "區", "區議員", "列席", "。", "離島區", "議員"
}


def fmm_segment(text, dictionary):
    max_len = max(len(w) for w in dictionary)
    i = 0
    out = []
    while i < len(text):
        matched = None
        for L in range(min(max_len, len(text) - i), 0, -1):
            cand = text[i:i+L]
            if cand in dictionary:
                matched = cand
                break
        if matched is None:
            matched = text[i]
        out.append(matched)
        i += len(matched)
    return out


def bmm_segment(text, dictionary):
    max_len = max(len(w) for w in dictionary)
    i = len(text)
    out = []
    while i > 0:
        matched = None
        for L in range(min(max_len, i), 0, -1):
            start = i - L
            cand = text[start:i]
            if cand in dictionary:
                matched = cand
                break
        if matched is None:
            matched = text[i-1:i]
        out.append(matched)
        i -= len(matched)
    return list(reversed(out))


print("=== Self-built Results ===")
print("FMM:", " / ".join(fmm_segment(sentence, word_dict)))
print("BMM:", " / ".join(bmm_segment(sentence, word_dict)))


# ----------------------------
# NLTK baseline
# ----------------------------
import nltk
print("\n=== NLTK Tokenization Result ===")
try:
    nltk_result = nltk.word_tokenize(sentence)
    print(nltk_result)
except Exception as e:
    print("NLTK failed to tokenize Chinese properly.")
    print("Error:", e)


# ----------------------------
# Jieba segmentation
# ----------------------------
import jieba
print("\n=== Jieba Segmentation Result ===")
jieba_result = list(jieba.cut(sentence))
print(" / ".join(jieba_result))

print("\n=== Jieba Full Mode ===")
print(" / ".join(jieba.cut(sentence, cut_all=True)))

print("\n=== Jieba Search Mode ===")
print(" / ".join(jieba.cut_for_search(sentence)))


print("\n=== Short Discussion ===")
print("1) NLTK is mainly English-oriented, so Chinese tokenization is weak by default.")
print("2) FMM/BMM are dictionary-rule methods, jieba combines dictionary + statistics.")
print("3) For ambiguity, jieba is usually more robust than pure FMM/BMM.")

# %% [markdown]
# ---
#
# ## 🎉 Tutorial Wrap‑Up & Submission Reminder
#
# Congratulations on completing **Week 3’s tutorial** for **CBS5502**!
# You have taken an important step into **Natural Language Processing (NLP)** by:
#
# - ✅ Understanding **Chinese Word Segmentation**
# - ✅ Implementing **Forward Maximum Matching (FMM)**
# - ✅ Extending it to **Backward Maximum Matching (BMM)**
# - ✅ Comparing rule‑based methods with real NLP tools (**NLTK & Jieba**)
# - ✅ Reflecting on **word meaning resolution and ambiguity**
#
# These skills form a **critical foundation** for more advanced NLP models and techniques.
#
# ---
#
# ## 📌 Participation Submission Reminder
#
# Please remember to submit your participation work, which consists of completing **Exercises 1 and 2** to practice this week’s learning.
#
# ### 📂 What to Submit
# - ✅ Your completed **Week 3 Participation `yourname.ipynb` notebook**
#
# ### 📍 Where to Submit
# - **Blackboard (BB)**
# - Folder: **“Week 3 Participation”**
#
# ### ⏰ Deadline
# - **By the end of Week 3**
# - **📅 February 1, 2026**
#
# ⚠️ Late submissions may affect your participation grade, so please plan accordingly.
#
# ---
#
# ## 💡 Final Notes
#
# - Make sure your notebook **runs without errors**
# - Include **code, outputs, and brief reflections**
# - Clearly show your work on **FMM, BMM, and tool comparisons**
#
# If you have any questions, feel free to ask during tutorials or on the course forum.
#
# ---
#
# ✨ **Well done, and keep up the great work!**
# We look forward to exploring more exciting NLP topics with you in the coming weeks 🚀
